# %% [markdown]
# # Dataset Analysis: movie_cleaned_20260117_033108.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('movie_cleaned_20260117_033108.csv')

# %% [markdown]
# ## Dataset Information

# %%
print('Total Rows:', df.shape[0])print('Total Columns:', df.shape[1])

# %% [markdown]
# ### Basic Statistics

# %%
df.describe()

# %% [markdown]
# ### Data Exploration

# %%
print('First 5 Rows:')print(df.head())

# %% [markdown]
# ## Column Analysis

# %%
print('Column Information:')print(df.info())

# %%
print('Column Types:')print(df.dtypes)

# %%
print('Popular Movies:')print(df.nlargest(10, 'Popularity'))
